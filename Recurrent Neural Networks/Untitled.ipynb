# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import tensorflow as tf
#       2 import tensorflow_hub as hub
# ----> 3 import tensorflow_text as text
#
# ModuleNotFoundError: No module named 'tensorflow_text'

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
import pandas as pd
df = pd.read_excel('doctorsBrain.xlsx')

# %%
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
#
#                                           Unnamed: 3     Unnamed: 4  \
# 0                                                NaN            NaN
# 1                                         P_complain  P_temperature
# 2  general belly pain or discomfort, which may co...            NaN
#
#   Unnamed: 5 Unnamed: 6           Unnamed: 7          Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN                  NaN                 NaN        NaN
# 1   P_weight    P_pulse  P_recommended_drugs  P_recommended_Test  P_disease
# 2        NaN        NaN                  NaN                 NaN        NaN
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# 2         NaN

# %%
df.columns = df.iloc[1]

# %%
df = df.reset_index(drop=True)

# %%
df.sample(3)
# Out:
# 1   NaN NaN NaN                                         P_complain  \
# 103 NaN NaN NaN  Symptoms of earwax build-up include:\n\nhearin...
# 44  NaN NaN NaN  Bowel polyps do not usually cause any symptoms...
# 291 NaN NaN NaN  feeling thirsty.\ndark yellow and strong-smell...
#
# 1   P_temperature P_weight P_pulse P_recommended_drugs P_recommended_Test  \
# 103           NaN      NaN     NaN                 NaN                NaN
# 44            NaN      NaN     NaN                 NaN                NaN
# 291           NaN      NaN     NaN                 NaN                NaN
#
# 1          P_disease  NaN
# 103  Earwax build-up  NaN
# 44      Bowel polyps  NaN
# 291           Thirst  NaN

# %%
df.sample(2)
# Out:
# 1   NaN NaN NaN                                         P_complain  \
# 285 NaN NaN NaN  The main symptom of supraventricular tachycard...
# 156 NaN NaN NaN  The main symptom of hyperhidrosis is heavy swe...
#
# 1   P_temperature P_weight P_pulse P_recommended_drugs P_recommended_Test  \
# 285           NaN      NaN     NaN                 NaN                NaN
# 156           NaN      NaN     NaN                 NaN                NaN
#
# 1                       P_disease  NaN
# 285  Supraventricular tachycardia  NaN
# 156                 Hyperhidrosis  NaN

# %%
dis_key = {}
count = 1

# %%
for disease in df['P_disease']:
    
    dis_key.update({disease : count})
    count = count + 1

# %%
dis_key
# Out:
# {nan: 3,
#  'P_disease': 2,
#  'Acne': 4,
#  'Acute Cholecystitis': 5,
#  'Acute lymphoblastic leukaemia': 6,
#  'Acute lymphoblastic leukaemia In Children': 7,
#  'Acute lymphoblastic leukaemia In teanagers and young Adults': 8,
#  'Acute Myeloid Leukaemia': 9,
#  'Acute Myeloid Leukaemia in Children': 10,
#  'Acute Myeloid Leukaemia in teanagers and young adults': 11,
#  'Acute Pancreatitis': 12,
#  'Adenomyosis': 13,
#  "Addison's disease": 14,
#  'Alcohol related liver disease': 15,
#  'allergic rhinitis': 16,
#  'Allergies': 17,
#  "alzheimer's disease": 18,
#  'Anal Cancer': 19,
#  'anaphylaxis': 20,
#  'Angina': 21,
#  'Angioedema': 22,
#  'ankylosing spondylitis': 23,
#  'anorexia nervosa': 24,
#  'Anxiety': 25,
#  'Anxiety disorders in children': 26,
#  'Appendicitis': 27,
#  'arterial thrombosis': 28,
#  'arthritis': 29,
#  'asbestosis': 30,
#  'asthma': 31,
#  'atopic eczema': 32,
#  'Atrial Fibrillation': 33,
#  'Bacterial Vaginosis': 34,
# ...

# %%
diseas_class_list = []
for val in dis_key.values():
  
    diseas_class_list.append(val)

# %%
len(diseas_class_list)
# Out:
# 323

# %%
df.shape
# Out:
# (324, 11)

# %%
df = df.iloc[2:]

# %%
df.head(4)
# Out:
# 1 NaN NaN NaN                                         P_complain  \
# 2 NaN NaN NaN  general belly pain or discomfort, which may co...
# 3 NaN NaN NaN  Acne commonly appears on the face and shoulder...
# 4 NaN NaN NaN  sudden sharp pain in the upper right side of y...
# 5 NaN NaN NaN  pale skin, feeling tired and breathless, havin...
#
# 1 P_temperature P_weight P_pulse P_recommended_drugs P_recommended_Test  \
# 2           NaN      NaN     NaN                 NaN                NaN
# 3           NaN      NaN     NaN                 NaN                NaN
# 4           NaN      NaN     NaN                 NaN                NaN
# 5           NaN      NaN     NaN                 NaN                NaN
#
# 1                      P_disease  NaN
# 2                            NaN  NaN
# 3                           Acne  NaN
# 4            Acute Cholecystitis  NaN
# 5  Acute lymphoblastic leukaemia  NaN

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\PROBOOK 450\AppData\Local\Temp\ipykernel_8656\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.head(4)
# Out:
# Empty DataFrame
# Columns: [nan, nan, nan, P_complain, P_temperature, P_weight, P_pulse, P_recommended_drugs, P_recommended_Test, P_disease, nan]
# Index: []

# %%
x = df['Unnamed: 3']
y = diseas_class_list
